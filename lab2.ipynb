# %% [markdown]
# PV-202 Aladib Yazan
#
# Laboratory Work №2. Clustering
#
# Data on mortality in heart failure (heart_failure_clinical_records_dataset.csv)

# %%
import pandas as pd
from matplotlib import pyplot as plt

df = pd.read_csv('heart_failure_clinical_records_dataset.csv').drop(columns=['time', 'DEATH_EVENT'])
df
# Out:
#       age  anaemia  creatinine_phosphokinase  diabetes  ejection_fraction  \
# 0    75.0        0                       582         0                 20
# 1    55.0        0                      7861         0                 38
# 2    65.0        0                       146         0                 20
# 3    50.0        1                       111         0                 20
# 4    65.0        1                       160         1                 20
# ..    ...      ...                       ...       ...                ...
# 294  62.0        0                        61         1                 38
# 295  55.0        0                      1820         0                 38
# 296  45.0        0                      2060         1                 60
# 297  45.0        0                      2413         0                 38
# 298  50.0        0                       196         0                 45
#
#      high_blood_pressure  platelets  serum_creatinine  serum_sodium  sex  \
# 0                      1  265000.00               1.9           130    1
# 1                      0  263358.03               1.1           136    1
# 2                      0  162000.00               1.3           129    1
# 3                      0  210000.00               1.9           137    1
# 4                      0  327000.00               2.7           116    0
# ..                   ...        ...               ...           ...  ...
# 294                    1  155000.00               1.1           143    1
# 295                    0  270000.00               1.2           139    0
# 296                    0  742000.00               0.8           138    0
# 297                    0  140000.00               1.4           140    1
# 298                    0  395000.00               1.6           136    1
#
#      smoking
# 0          0
# 1          0
# 2          1
# 3          0
# 4          0
# ..       ...
# 294        1
# 295        0
# 296        0
# 297        1
# 298        1
#
# [299 rows x 11 columns]

# %% [markdown]
# Preliminary visualization

# %%
def print_graphics(data_frame, clustering_labels=None):
    plt.xlabel('Ejection Fraction')
    plt.ylabel('Creatine Kinase')
    plt.scatter(data_frame['ejection_fraction'], data_frame['creatinine_phosphokinase'], c=clustering_labels)
    plt.show()

    plt.xlabel('Ejection Fraction')
    plt.ylabel('Platelets')
    plt.scatter(data_frame['ejection_fraction'], data_frame['platelets'], c=clustering_labels)
    plt.show()

    plt.xlabel('Serum Sodium')
    plt.ylabel('Platelets')
    plt.scatter(data_frame['serum_sodium'], data_frame['platelets'], c=clustering_labels)
    plt.show()


print_graphics(df)

# %% [markdown]
# Data normalization

# %%
from sklearn.preprocessing import StandardScaler

data = StandardScaler().fit_transform(df.values)

# %% [markdown]
# Clustering using the K-means method (2 clusters)

# %%
from sklearn.cluster import KMeans

clustering = KMeans(n_clusters=2, n_init=12)
clustering.fit(data)

print_graphics(df, clustering.labels_)

# %% [markdown]
# Clustering using the K-means method (5 clusters)

# %%
clustering = KMeans(n_clusters=5, n_init=20)
clustering.fit(df)

print_graphics(df, clustering.labels_)

# %% [markdown]
# Clustering using the agglomerative hierarchical method (2 clusters)

# %%
from sklearn.cluster import AgglomerativeClustering

clustering = AgglomerativeClustering(n_clusters=2, metric='mahalanobis', linkage='complete')
clustering.fit(data)

print_graphics(df, clustering.labels_)

# %% [markdown]
# Clustering using the agglomerative hierarchical method (5 clusters)

# %%
clustering = AgglomerativeClustering(n_clusters=5, metric='mahalanobis', linkage='complete')
clustering.fit(data)

print_graphics(df, clustering.labels_)
